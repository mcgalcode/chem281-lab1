# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
with open("sim_output.json", "r+") as f:
    output = np.array(json.load(f))
    
for i in range(output.shape[1]):
    plt.plot(output[:, i], '.', label='atom {}'.format(i))
plt.xlabel(r'Step')
plt.ylabel(r'$x$-Position/Å')
plt.legend(frameon=False)
plt.show()

# %%
r = np.linspace(1.95, 2.2, 100)
plt.plot(r, lj.lj_force(r, 0.1, sigma))
plt.xlabel(r'$r$/Å')
plt.ylabel(r'$f$/eVÅ$^{-1}$')
plt.show()
